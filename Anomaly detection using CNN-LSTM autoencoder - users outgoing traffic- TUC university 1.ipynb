# %% [markdown]
# ***Import libraries***

# %%
import pandas as pd
import numpy as np

from math import sqrt
import math
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM, Flatten, Input
import tensorflow as tf

from tensorflow.python.keras.preprocessing.sequence import TimeseriesGenerator

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

import warnings
warnings.filterwarnings('ignore')

import sklearn
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ***Load data***

# %%
#********Load data**************************

data_raw = []
for week in range(1, 10):
    week_data = pd.read_csv('../Paper1/usersout{}.csv'.format(week)).values
    data_raw.append(week_data)
    
data= np.array(data_raw)
dataset= np.concatenate(data)
dataset=pd.DataFrame(dataset)
dataset.head()
# Out:
#      0
# 0  650
# 1  664
# 2  664
# 3  664
# 4  664

# %%
#******************Z score outlier detection ****************
def remove_outliers(data, threshold=5):
    mean= data.mean()
    std= data.std()
    idx= np.abs((data-mean)/std) <= threshold
    return data[idx].reshape(-1, 1)

# %%
dataset= np.array(dataset)
print('dataset with outlier', dataset.shape)
dataset= dataset.astype('float32')
dataset= remove_outliers(dataset)
print('dataset after removing outlier', dataset.shape)
# Out:
# dataset with outlier (154583, 1)
# dataset after removing outlier (154092, 1)

# %%
dataset=pd.DataFrame(dataset)
dataset.columns = ['Traffic']
dataset.head()
# Out:
#    Traffic
# 0    650.0
# 1    664.0
# 2    664.0
# 3    664.0
# 4    664.0

# %% [markdown]
# ***Data preprocessing***

# %%
#checking for missing values
dataset.isnull().values.any()
# Out:
# False

# %%
#Check for missing values
print("total number of rows : {0}".format(len(dataset)))
print("number of rows missing traffic: {0}".format(len(dataset.loc[dataset['Traffic'] == 0])))
print(dataset.head())

#Fill missing values
dataset = dataset.replace(0, np.nan) 
dataset.interpolate(method= 'linear', inplace=True)

#Check how many other missing(zero) values
print("total number of rows : {0}".format(len(dataset)))
print("number of rows missing traffic: {0}".format(len(dataset.loc[dataset['Traffic'] == 0])))
print(dataset.head())
# Out:
# total number of rows : 154092
# number of rows missing traffic: 0
#    Traffic
# 0    650.0
# 1    664.0
# 2    664.0
# 3    664.0
# 4    664.0
# total number of rows : 154092
# number of rows missing traffic: 0
#    Traffic
# 0    650.0
# 1    664.0
# 2    664.0
# 3    664.0
# 4    664.0

# %%
#plt.plot(dataset, label='Traffic')
dataset.plot(figsize=(12,5))
plt.ylabel('Traffic')
plt.title('Email trafic time Series')
sns.despine(top=True)
plt.show();

# %%
#dataset= dataset.astype('float64')

# %%
# split into train and test dataset

train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size], dataset[train_size:len(dataset)]
print(train.shape, test.shape)
# Out:
# (123273, 1) (30819, 1)

# %%
#Normalise the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler = scaler.fit(train[['Traffic']])

train['Traffic'] = scaler.transform(train[['Traffic']])
test['Traffic'] = scaler.transform(test[['Traffic']])

# %% [markdown]
# ***Convert to a lagged time series data***

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
TIME_STEPS = 3

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train[['Traffic']], train, TIME_STEPS)
X_test, y_test = create_dataset(test[['Traffic']], test, TIME_STEPS)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (123270, 3, 1) (123270, 1)
# (30816, 3, 1) (30816, 1)

# %% [markdown]
# ***Create a batch generator to feed the data to the model in batches***

# %%
#******************* Batch generator****************************
def batch_generator(X, Y, batch_size):
    """
    Generator function for creating random batches of training-data.
    """
    while True:
        num_records = X.shape[0]
        timesteps = X.shape[1]
        num_batches = num_records // batch_size
        for idx in range(num_batches):
            x = X[idx*batch_size:(idx+1)*batch_size, :]
            y = Y[idx*batch_size:(idx+1)*batch_size, :]
            yield (x, y)

# %%
#***********We then create the batch generator***********************
batch_size=8
generator = batch_generator(X_train, X_train, batch_size)
validation_data = batch_generator(X_test, X_test, batch_size)

x_batch, y_batch = next(generator)

print(x_batch.shape)
print(y_batch.shape)
# Out:
# (8, 3, 1)
# (8, 3, 1)

# %% [markdown]
# ***Model***

# %%
#CNN LSTM autoencoder
model = tf.keras.Sequential()


model.add(tf.keras.layers.Conv1D(filters=16,kernel_size=2 ,padding='valid',activation='relu',strides=1,
                    input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.RepeatVector(n=X_train.shape[1]))

# Decoder
model.add(tf.keras.layers.LSTM(units=128, return_sequences=True))
model.add(tf.keras.layers.LSTM(units=128, return_sequences=True))
#model.add(tf.keras.layers.Dropout(rate=0.2))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=X_train.shape[2])))



model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2, 16)             48
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1, 16)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 16)                0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 3, 16)             0
# _________________________________________________________________
# unified_lstm (UnifiedLSTM)   (None, 3, 128)            74240
# _________________________________________________________________
# unified_lstm_1 (UnifiedLSTM) (None, 3, 128)            131584
# _________________________________________________________________
# time_distributed (TimeDistri (None, 3, 1)              129
# =================================================================
# Total params: 206,001
# Trainable params: 206,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
#***Train the model***
history= model.fit_generator(generator=generator,
                    epochs=500,
                    steps_per_epoch=5, validation_data=validation_data, validation_steps=8, 
                             shuffle=False, verbose=1)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 2s 374ms/step - loss: 1.9240 - mae: 1.3461 - val_loss: 0.4900 - val_mae: 0.6998
# Epoch 2/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6196 - mae: 1.2038 - val_loss: 0.5809 - val_mae: 0.7609
# Epoch 3/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7723 - mae: 0.7805 - val_loss: 0.7288 - val_mae: 0.8487
# Epoch 4/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5473 - mae: 0.8770 - val_loss: 0.6845 - val_mae: 0.8246
# Epoch 5/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5436 - mae: 0.6674 - val_loss: 0.6196 - val_mae: 0.7863
# Epoch 6/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6016 - mae: 0.6081 - val_loss: 0.5993 - val_mae: 0.7737
# Epoch 7/500
# 5/5 [==============================] - 0s 27ms/step - loss: 3.3107 - mae: 1.5835 - val_loss: 0.3870 - val_mae: 0.6186
# Epoch 8/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4346 - mae: 0.5339 - val_loss: 0.2585 - val_mae: 0.4873
# Epoch 9/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3822 - mae: 0.5265 - val_loss: 0.1985 - val_mae: 0.3976
# Epoch 10/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3472 - mae: 0.5099 - val_loss: 0.1729 - val_mae: 0.3434
# Epoch 11/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2902 - mae: 0.4544 - val_loss: 0.1622 - val_mae: 0.3198
# Epoch 12/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2385 - mae: 0.3895 - val_loss: 0.1576 - val_mae: 0.3184
# Epoch 13/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1830 - mae: 0.3182 - val_loss: 0.1560 - val_mae: 0.3176
# Epoch 14/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.1027 - mae: 0.4855 - val_loss: 0.1609 - val_mae: 0.3196
# Epoch 15/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0877 - mae: 0.1804 - val_loss: 0.1852 - val_mae: 0.3775
# Epoch 16/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.
500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0068 - mae: 0.0733 - val_loss: 0.0146 - val_mae: 0.0902
# Epoch 389/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0242 - mae: 0.0974 - val_loss: 0.0025 - val_mae: 0.0293
# Epoch 390/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5963 - mae: 0.2980 - val_loss: 0.0039 - val_mae: 0.0516
# Epoch 391/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1449 - mae: 0.1352 - val_loss: 0.3000 - val_mae: 0.1831
# Epoch 392/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0234 - mae: 0.0659 - val_loss: 0.0141 - val_mae: 0.0506
# Epoch 393/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1151 - mae: 0.0873 - val_loss: 0.0102 - val_mae: 0.0346
# Epoch 394/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0032 - mae: 0.0333 - val_loss: 0.0180 - val_mae: 0.0561
# Epoch 395/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0133 - mae: 0.0640 - val_loss: 0.0022 - val_mae: 0.0365
# Epoch 396/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0319 - mae: 0.0911 - val_loss: 0.0753 - val_mae: 0.0827
# Epoch 397/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0016 - mae: 0.0329 - val_loss: 0.0038 - val_mae: 0.0394
# Epoch 398/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0134 - mae: 0.0473 - val_loss: 0.0394 - val_mae: 0.0507
# Epoch 399/500
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0065 - val_mae: 0.0519
# Epoch 400/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0057 - mae: 0.0315 - val_loss: 0.5288 - val_mae: 0.2483
# Epoch 401/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0301 - mae: 0.0595 - val_loss: 0.0027 - val_mae: 0.0374
# Epoch 402/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0472 - mae: 0.0830 - val_loss: 0.1829 - val_mae: 0.0989
# Epoch 403/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0308 - mae: 0.0787 - val_loss: 0.0531 - val_mae: 0.0967
# Epoch 404/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0033 - mae: 0.0342 - val_loss: 0.1785 - val_mae: 0.1382
# Epoch 405/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0356 - mae: 0.1003 - val_loss: 0.1472 - val_mae: 0.1484
# Epoch 406/500
# 5/5 [==============================] - 0s 28ms/step - loss: 8.5553e-04 - mae: 0.0245 - val_loss: 0.0024 - val_mae: 0.0376
# Epoch 407/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0747 - mae: 0.1258 - val_loss: 0.0959 - val_mae: 0.2591
# Epoch 408/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0965 - mae: 0.1300 - val_loss: 0.1015 - val_mae: 0.2686
# Epoch 409/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0960 - mae: 0.1201 - val_loss: 0.1089 - val_mae: 0.2799
# Epoch 410/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5482 - mae: 0.4321 - val_loss: 0.1041 - val_mae: 0.2876
# Epoch 411/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5436 - mae: 0.5660 - val_loss: 0.1256 - val_mae: 0.3195
# Epoch 412/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0706 - mae: 0.1699 - val_loss: 0.1388 - val_mae: 0.3254
# Epoch 413/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0064 - mae: 0.0643 - val_loss: 0.1624 - val_mae: 0.3858
# Epoch 414/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0286 - mae: 0.0792 - val_loss: 0.1787 - val_mae: 0.4079
# Epoch 415/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0020 - mae: 0.0333 - val_loss: 0.1848 - val_mae: 0.4094
# Epoch 416/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0065 - mae: 0.0561 - val_loss: 0.2001 - val_mae: 0.4224
# Epoch 417/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0072 - mae: 0.0412 - val_loss: 0.2051 - val_mae: 0.4233
# Epoch 418/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0960 - mae: 0.0993 - val_loss: 0.2027 - val_mae: 0.4207
# Epoch 419/500
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7297 - mae: 0.3206 - val_loss: 0.1646 - val_mae: 0.3743
# Epoch 420/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1788 - mae: 0.1365 - val_loss: 0.0938 - val_mae: 0.2679
# Epoch 421/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4820 - mae: 0.2394 - val_loss: 0.0602 - val_mae: 0.2154
# Epoch 422/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0091 - mae: 0.0647 - val_loss: 0.0370 - val_mae: 0.1629
# Epoch 423/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6059 - mae: 0.3176 - val_loss: 0.0208 - val_mae: 0.1065
# Epoch 424/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0044 - mae: 0.0386 - val_loss: 0.0136 - val_mae: 0.0933
# Epoch 425/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4005 - mae: 0.2200 - val_loss: 0.0265 - val_mae: 0.1483
# Epoch 426/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1331 - mae: 0.1346 - val_loss: 0.0361 - val_mae: 0.1785
# Epoch 427/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0013 - mae: 0.0246 - val_loss: 0.0462 - val_mae: 0.2035
# Epoch 428/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0024 - mae: 0.0291 - val_loss: 0.0513 - val_mae: 0.2152
# Epoch 429/500
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0133 - mae: 0.0496 - val_loss: 0.0538 - val_mae: 0.2205
# Epoch 430/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0834 - mae: 0.0933 - val_loss: 0.0526 - val_mae: 0.2196
# Epoch 431/500
# 5/5 [==============================] - 0s 28ms/step - loss: 9.5250e-04 - mae: 0.0185 - val_loss: 0.0393 - val_mae: 0.1950
# Epoch 432/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.2811e-04 - mae: 0.0080 - val_loss: 0.0324 - val_mae: 0.1789
# Epoch 433/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0090 - mae: 0.0517 - val_loss: 0.0290 - val_mae: 0.1696
# Epoch 434/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0736 - mae: 0.0913 - val_loss: 0.0336 - val_mae: 0.1831
# Epoch 435/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0477 - mae: 0.0925 - val_loss: 0.0368 - val_mae: 0.1914
# Epoch 436/500
# 5/5 [==============================] - 0s 28ms/step - loss: 8.3340e-04 - mae: 0.0210 - val_loss: 0.0387 - val_mae: 0.1963
# Epoch 437/500
# 5/5 [==============================] - 0s 28ms/step - loss: 3.9708e-04 - mae: 0.0163 - val_loss: 0.0391 - val_mae: 0.1972
# Epoch 438/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.2067e-04 - mae: 0.0092 - val_loss: 0.0385 - val_mae: 0.1960
# Epoch 439/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0026 - mae: 0.0206 - val_loss: 0.0382 - val_mae: 0.1952
# Epoch 440/500
# 5/5 [==============================] - 0s 28ms/step - loss: 9.7885e-05 - mae: 0.0082 - val_loss: 0.0386 - val_mae: 0.1961
# Epoch 441/500
# 5/5 [==============================] - 0s 28ms/step - loss: 7.9924e-05 - mae: 0.0078 - val_loss: 0.0388 - val_mae: 0.1966
# Epoch 442/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.0037e-05 - mae: 0.0040 - val_loss: 0.0392 - val_mae: 0.1975
# Epoch 443/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0014 - mae: 0.0202 - val_loss: 0.0390 - val_mae: 0.1971
# Epoch 444/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0087 - mae: 0.0456 - val_loss: 0.0391 - val_mae: 0.1972
# Epoch 445/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0910 - mae: 0.0962 - val_loss: 0.0416 - val_mae: 0.2033
# Epoch 446/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1327 - mae: 0.1632 - val_loss: 0.0300 - val_mae: 0.1708
# Epoch 447/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0195 - mae: 0.0667 - val_loss: 0.0236 - val_mae: 0.1415
# Epoch 448/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0536 - mae: 0.1051 - val_loss: 0.0217 - val_mae: 0.1242
# Epoch 449/500
# 5/5 [==============================] - 0s 28ms/step - loss: 4.8800e-04 - mae: 0.0194 - val_loss: 0.0222 - val_mae: 0.1179
# Epoch 450/500
# 5/5 [==============================] - 0s 29ms/step - loss: 2.9875e-04 - mae: 0.0143 - val_loss: 0.0224 - val_mae: 0.1122
# Epoch 451/500
# 5/5 [==============================] - 0s 28ms/step - loss: 5.4023e-04 - mae: 0.0176 - val_loss: 0.0223 - val_mae: 0.1077
# Epoch 452/500
# 5/5 [==============================] - 0s 28ms/step - loss: 5
500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.8255e-04 - mae: 0.0088 - val_loss: 0.0669 - val_mae: 0.1958
# Epoch 483/500
# 5/5 [==============================] - 0s 28ms/step - loss: 8.2960e-05 - mae: 0.0073 - val_loss: 0.0670 - val_mae: 0.1962
# Epoch 484/500
# 5/5 [==============================] - 0s 28ms/step - loss: 6.0766e-04 - mae: 0.0131 - val_loss: 0.0670 - val_mae: 0.1963
# Epoch 485/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0004e-04 - mae: 0.0075 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 486/500
# 5/5 [==============================] - 0s 28ms/step - loss: 7.5675e-05 - mae: 0.0068 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 487/500
# 5/5 [==============================] - 0s 28ms/step - loss: 4.7632e-05 - mae: 0.0050 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 488/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.6352e-05 - mae: 0.0035 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 489/500
# 5/5 [==============================] - 0s 28ms/step - loss: 3.4948e-05 - mae: 0.0038 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 490/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.1327e-05 - mae: 0.0024 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 491/500
# 5/5 [==============================] - 0s 28ms/step - loss: 7.6717e-06 - mae: 0.0020 - val_loss: 0.0671 - val_mae: 0.1964
# Epoch 492/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0015 - mae: 0.0143 - val_loss: 0.0670 - val_mae: 0.1963
# Epoch 493/500
# 5/5 [==============================] - 0s 27ms/step - loss: 7.3633e-04 - mae: 0.0186 - val_loss: 0.0668 - val_mae: 0.1962
# Epoch 494/500
# 5/5 [==============================] - 0s 28ms/step - loss: 9.4061e-04 - mae: 0.0217 - val_loss: 0.0671 - val_mae: 0.1961
# Epoch 495/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0027 - mae: 0.0234 - val_loss: 0.0669 - val_mae: 0.1953
# Epoch 496/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 0.0669 - val_mae: 0.1953
# Epoch 497/500
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0187 - mae: 0.0621 - val_loss: 0.0658 - val_mae: 0.1949
# Epoch 498/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0015 - mae: 0.0380 - val_loss: 0.0662 - val_mae: 0.1961
# Epoch 499/500
# 5/5 [==============================] - 0s 28ms/step - loss: 4.0267e-04 - mae: 0.0170 - val_loss: 0.0674 - val_mae: 0.1984
# Epoch 500/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0222 - mae: 0.0556 - val_loss: 0.0668 - val_mae: 0.1989

# %% [raw]
# history = model.fit(X_train, X_train, epochs=2, batch_size=32, validation_split=0.1,shuffle=False)

# %% [markdown]
# ***Plot the model training loss***

# %%
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.ylabel('Loss (MAE)')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ***Reconstruction error scores***

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (30816, 3, 1)
# (30816, 1)

# %%
# model predict
test_x_predictions = model.predict(X_test)

# %%
# Reshape from 3D to 2D
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1]))
test_x_predictions = test_x_predictions.reshape((test_x_predictions.shape[0], test_x_predictions.shape[1]))

# Reconstruction Mean absolute Error score
def mae(X_test, test_x_predictions):
    return sklearn.metrics.mean_absolute_error(X_test, test_x_predictions)

MAE= mae(X_test, test_x_predictions)
print('Reconstruction_error MAE', MAE)

# Reconstruction Mean square Error score
def mse(X_test, test_x_predictions):
    return sklearn.metrics.mean_squared_error(X_test, test_x_predictions)

MSE= mse(X_test, test_x_predictions)
print('Reconstruction_error MSE',MSE)

# Reconstruction Root mean square error score
def rmse(X_test, test_x_predictions):
    return math.sqrt(sklearn.metrics.mean_squared_error(X_test, test_x_predictions)) 

RMSE= rmse(X_test, test_x_predictions)
print('Reconstruction_error RMSE',RMSE)
# Out:
# Reconstruction_error MAE 0.15220315216589086
# Reconstruction_error MSE 0.0589660290103676
# Reconstruction_error RMSE 0.24282921778560257

# %% [raw]
# # *************************invert predictions**************************
# trainPredict = model.predict(X_train)
#
# trainPredict_inv = scaler.inverse_transform(trainPredict)
# train_y_inv = scaler.inverse_transform(y_train)
#
# testPredict_inv = scaler.inverse_transform(test_x_predictions)
# test_y_inv = scaler.inverse_transform(y_test)

# %%
# *************************invert predictions**************************
trainPredict = model.predict(X_train)

trainPredict_inv = scaler.inverse_transform(trainPredict)
train_X_inv = scaler.inverse_transform(X_train)

testPredict_inv = scaler.inverse_transform(test_x_predictions)
test_X_inv = scaler.inverse_transform(X_test)

# %%
#********************* Actual value, Predicted value and Prediction Error ***************

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot(test_X_inv[:,0], label="True value", linewidth=1,linestyle="--",color= 'green')
plt.plot(testPredict_inv[:,0], label="Predicted value", linewidth=1,color='blue')

error = abs(test_X_inv[:,0] - testPredict_inv[:,0])
plt.plot(error, label='Error',color= 'orange', linewidth=1, linestyle="--")
plt.legend()
plt.show()

#******************************* True value vs Prediction **********************/

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot (test_X_inv[:,0], label="True value", linewidth=1,color= 'green', linestyle="--")
plt.plot(testPredict_inv[:,0], label="Predicted value", linewidth=1,color='blue')
plt.legend()
plt.show()

# %% [markdown]
# ***Loss distribution***

# %% [raw]
# By plotting the distribution of the calculated loss in the training set, we can determine a suitable threshold value for identifying an anomaly. In doing this, one can make sure that this threshold is set above the “noise level” so that false positives are not triggered.

# %%
# plot the loss distribution of the training set

X_pred= model.predict(X_train)
Loss_mae = np.mean(np.abs(X_pred-X_train), axis=1)
#plt.figure(figsize =(16,9), dpi=80)
#plt.title('Loss distribution', fontsize=16)
sns.distplot(Loss_mae, bins=20, kde=True, color='blue');
#plt.xlim([0.0,.5])

# %%
X_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(X_train_pred - X_train), axis=1)

#lets look at the error
plt.figure(figsize= (8, 3), dpi=80)
sns.distplot(train_mae_loss, bins=20, kde=True, color='blue');
plt.xlim([0.0, 5])
# Out:
# (0.0, 5)

# %% [raw]
# Based on the above loss distribution, let’s try a threshold value of 0.65 for flagging an anomaly. We then calculate the reconstruction loss in the training and test sets to determine when the sensor readings cross the anomaly threshold.

# %% [markdown]
# ***Threshold for flagging an anomaly***

# %%
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
test_x_predictions = model.predict(X_test)
mae = np.mean(np.power(X_test - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame(data=np.concatenate((mae, y_test), axis=1), columns=["Reconstruction_error", "True_class"])
error_df.describe()
# Out:
#        Reconstruction_error    True_class
# count          30816.000000  30816.000000
# mean               0.058966     -0.075346
# std                0.229759      1.015239
# min                0.000011     -1.478697
# 25%                0.002056     -1.453800
# 50%                0.066813      0.652242
# 75%                0.066813      0.652242
# max               13.050782      6.355183

# %%
THRESHOLD = 0.001

error_df = pd.DataFrame(index=test[TIME_STEPS:].index)
error_df['loss'] = mae
error_df['threshold'] = THRESHOLD
error_df['True_class']= y_test
error_df['Reconstruction_error']= mae

error_df['anomaly'] = error_df.loss > error_df.threshold
error_df['normal'] = error_df.True_class <= error_df.threshold

#error_df["anomaly"] = (error_df["Reconstruction_error"]>THRESHOLD)
#error_df["normal"] = (error_df["True_class"]<=THRESHOLD)



predicted_test_anomalies = [1 if e > THRESHOLD else 0 for e in error_df.Reconstruction_error.values]
error_df['anomaly_predicted']= predicted_test_anomalies

print(classification_report(error_df.normal, predicted_test_anomalies))

#error_df["anomaly"] = (error_df.Reconstruction_error > THRESHOLD).astype(int)
#error_df["normal"] = (error_df.True_class <= THRESHOLD).astype(int)

error_df['Traffic'] = test[TIME_STEPS:]
# Out:
#               precision    recall  f1-score   support
#
#        False       0.01      0.00      0.00     19989
#         True       0.33      0.92      0.49     10827
#
#    micro avg       0.32      0.32      0.32     30816
#    macro avg       0.17      0.46      0.25     30816
# weighted avg       0.12      0.32      0.17     30816

# %%
plt.plot(error_df.index, error_df.loss, label='loss')
plt.plot(error_df.index, error_df.threshold, label='threshold')
plt.xticks(rotation=25)
plt.legend();

# %%
anomalies = error_df[error_df.anomaly == True]
anomalies.head()
# Out:
#             loss  threshold  True_class  Reconstruction_error  anomaly  \
# 123276  0.066813      0.001    0.652242              0.066813     True
# 123277  0.066813      0.001    0.652242              0.066813     True
# 123278  0.066813      0.001    0.652242              0.066813     True
# 123279  0.066813      0.001    0.652242              0.066813     True
# 123280  0.066813      0.001    0.652242              0.066813     True
#
#         normal  anomaly_predicted   Traffic
# 123276   False                  1  0.652242
# 123277   False                  1  0.652242
# 123278   False                  1  0.652242
# 123279   False                  1  0.652242
# 123280   False                  1  0.652242

# %%
plt.plot(
  test[TIME_STEPS:].index, 
  scaler.inverse_transform(test[TIME_STEPS:].Traffic), 
  label='Email traffic'
);

sns.scatterplot(
  anomalies.index,
  scaler.inverse_transform(anomalies.Traffic),
  color=sns.color_palette()[3],
  s=100,
  label='anomaly'
)

plt.xticks(rotation=25)
plt.legend();

# %%
sns.scatterplot(
  anomalies.index,
  scaler.inverse_transform(anomalies.Traffic),
  color=sns.color_palette()[3],
  s=100,
  label='anomaly'
)
plt.xticks(rotation=25)
plt.legend()

# %%
print(classification_report(error_df["normal"], error_df["anomaly"]))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.01      0.00      0.00     19989
#         True       0.33      0.92      0.49     10827
#
#    micro avg       0.32      0.32      0.32     30816
#    macro avg       0.17      0.46      0.25     30816
# weighted avg       0.12      0.32      0.17     30816

# %%
# ROC curve
false_pos_rate, true_pos_rate, THRESHOLD = roc_curve(error_df["normal"], error_df["anomaly"])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth=5, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#Precision recall matrix
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df["normal"], error_df["anomaly"])
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=5)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=5)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %%
#Confusion matrix
LABELS = ["Normal", "Fraud"]
conf_matrix = confusion_matrix(error_df["normal"], error_df["anomaly"])

plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS,annot=True, fmt="d")
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
